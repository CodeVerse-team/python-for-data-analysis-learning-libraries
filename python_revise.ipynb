# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeVerse-team/python-for-data-analysis-learning-libraries/blob/main/python_revise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python 3 (Recap)
#
#
#
# ---
# In Python, we'd write Indentation in this way:

# %%
def add_numbers(x, y):
  return x + y

# %% [markdown]
# An `if-else` block in Javascript:
#
# ```
# let language = "Python"
#
# if(language === "Python"){
#     cosole.log("let the fun begin");
#   }
#   else{
#     console.log("Get your hands dirty");
# }
# ```

# %%
language = "Python"

if language == "PYthon":
  print("let the fun begin!")
  if language.endswith("3"):
    print("Python 3")
else:
  print("Get your hands dirty")
# Out:
# Get your hands dirty

# %% [markdown]
# # Comments
#
# You've seen comments in the previous blcok of code. they're prefixed with a pound/hashtag sign:

# %%
# this is a comment
# It doesn't produce any output

#It can be above
print("Hello World!") # next to..
# or below your code
# Out:
# Hello World!

# %% [markdown]
# # Variables
#
# We've defined a variable `language` in one of our previous examples. In python, you can set a variable at any time, in any block of code, by just assigning a valid name to any value name to any value you want:

# %%
name = "Mary"
print(name)
# Out:
# Mary

# %%
age = 30
print(age)
# Out:
# 30

# %% [markdown]
# Variables, once set, will be preserved:

# %%
print(name, "is", age, "years old.")
# Out:
# Mary is 30 years old.

# %% [markdown]
# # Data Types
#
# Python supports the most common data types, the usual suspects we could say:
#
# **Integers, type** `int`:
# Integers have unlimited magnitude.

# %%
#an int
age = 30
age
# Out:
# 30

# %%
type(age)
# Out:
# int

# %%
# a float
price = 2.50
price
# Out:
# 2.5

# %%
type(price)
# Out:
# float

# %%
0.1 * 3
# Out:
# 0.30000000000000004

# %%
from decimal import Decimal

# %%
Decimal('0.1') * 3
# Out:
# Decimal('0.3')

# %%
# String, type str

# created by double quotes:
print("Hello World!")
# Out:
# Hello World!

# %%
# single quotes
print('Hello World!')
# Out:
# Hello World!

# %%
type('Hello World!')
# Out:
# str

# %%
len('Hello')
# Out:
# 5

# %%
# Booleans, type -- bool
True
# Out:
# True

# %%
type(False)
# Out:
# bool

# %% [markdown]
# None, type `NoneType`

# %%
x = None
x
print(x)
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# `int`, `float`, `str` and `bool` objects an functions
#
# You'll often see some of these "keywords/names" used both as functions and as individual objects. When used as functions, their usage is to transform/cast objects into it's corresponding type. Example:

# %%
age_as_string = "28"

# %%
type(age_as_string)
# Out:
# str

# %%
int(age_as_string)
# Out:
# 28

# %%
age = int(age_as_string)

# %%
type(age)
# Out:
# int

# %% [markdown]
# Their use as objects is mainly associated with their type:

# %%
type(13) == int
# Out:
# True

# %% [markdown]
# # Functions
#
# We've seen coulple of funcitons defined aldread, but lets dig a little bit deeper. Functions in Python are very intuitive. Let's start with an exapmple of fucntion without parameters:

# %%
def hello():
  return "Hello World"

# %%
result = hello()
result
# Out:
# 'Hello World'

# %%
def empty():
  x = 3
  # return 33

result = empty()
print(result)
# Out:
# 33

# %%
# Receiving Parameters

def add (x, y):
  return x + y

# %%
add(2, 3)
# Out:
# 5

# %%
# we can also define functions that accept variable number of arguments, using the star args *

def add(*args):
  return sum(args)

# %%
add(1, 1, 1)
# Out:
# 3

# %%
add(1)
# Out:
# 1

# %% [markdown]
# # Operators
# Both arithmetic and boolean operators are available

# %%
3 + 3
# Out:
# 6

# %%
11 / 7
# Out:
# 1.5714285714285714

# %%
2 ** 3
# Out:
# 8

# %%
3 + 4 * 9
# Out:
# 39

# %%
6 + 7 * 7 - 2 ** 6
# Out:
# -9

# %% [markdown]
# # Boolean Operators
#
# Regular comparison operators are available:

# %%
7 > 3
# Out:
# True

# %%
8>= 8
# Out:
# True

# %%
8 > "abv"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2178063608.py in <cell line: 0>()
# ----> 1 8 > "abv"
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %%
True and True
# Out:
# True

# %%
not False
# Out:
# True

# %%
False or True
# Out:
# True

# %% [markdown]
# # Control Flow
#
# Python supports the most common control flow blocks. keep in mind they're defined with indentation.
#
# **if/else/ elif statements**

# %%
days_subscribed = 28

if days_subscribed >= 30:
  print("Loyal Customer")
elif days_subscribed >= 15:
  print("Halfway there")
elif days_subscribed >= 1:
  print("Builfing confidence")
else:
  print("Too early")
# Out:
# Halfway there

# %% [markdown]
# # For Loops
# For loops in Python are different than other languages, specially those C/java inspired languages. In Python, `For` loops are designed to iterate over collections (we'll see collections later). But keep that in mind.

# %%
names = ['Monica', 'Ross', 'Chandler', 'Joey', 'Rachel']

for name in names:
  print(name)
# Out:
# Monica
# Ross
# Chandler
# Joey
# Rachel

# %% [markdown]
# # While Loops

# %%
count = 0

while count < 3:
  print("Counting...")
  count += 1
# Out:
# Counting...
# Counting...
# Counting...

# %% [markdown]
# There's another block to mention, `try/except`, but it's in the Exceptions sections.
#
# ---
#
# # Collections
#
# Python has multiple versatile collection types, each with diferent features and capabilities. These are the most common collections we'll explore:
#
# *   Lists
# *   Tuples
# *   Dictornaries
# *   sets

# %%
# Lists

l = [3, 'Hello World', True]
len(l)
# Out:
# 3

# %%
l[0], l[1]
# Out:
# (3, 'Hello World')

# %%
# negative indices are also supported

l[-1], l[-2]
# Out:
# (True, 'Hello World')

# %%
l.append('Python')
l
# Out:
# [3, 'Hello World', True, 'Python', 'Python']

# %%
'Python' in l
# Out:
# True

# %%
'Ruby' in l
# Out:
# False

# %%
# Tuples
t = (3, 'Hello World', True)

# %%
t[0]
# Out:
# 3

# %%
t[-1]
# Out:
# True

# %%
'Hello World' in t
# Out:
# True

# %%
# Dictionaries

# %%
user = {
    "name": "Mary Smith",
    "email": "john.mckinley@examplepetstore.com",
    "age": 30,
    "subscribed": True
}

# %%
user
# Out:
# {'name': 'Mary Smith',
#  'email': 'john.mckinley@examplepetstore.com',
#  'age': 30,
#  'subscribed': True}

# %%
user['email']
# Out:
# 'john.mckinley@examplepetstore.com'

# %%
'age' in user
# Out:
# True

# %%
'last_name' in user
# Out:
# False

# %%
# Sets
# Sets are unordered collection which the unique characteristic thaty they only contain unique elements:

s = {2, 1, 3, 5, 7,3 , 5, 8,2,6 ,78 ,56}
s
# Out:
# {1, 2, 3, 5, 6, 7, 8, 56, 78}

# %%
# adding elements is done with the add mehtod
s.add(10)
s
# Out:
# {2, 3, 5, 6, 7, 8, 10, 56, 78}

# %%
# Removing elements can ve done with pop()
s.pop()
# Out:
# 1

# %%
6 in s
# Out:
# True

# %%
# Iterating Collections
l = [3, 'Hello World', True]

# %%
for elem in l:
  print(elem)
# Out:
# 3
# Hello World
# True

# %%
user
# Out:
# {'name': 'Mary Smith',
#  'email': 'john.mckinley@examplepetstore.com',
#  'age': 30,
#  'subscribed': True}

# %%
for key in user:
  print(key.upper())
# Out:
# NAME
# EMAIL
# AGE
# SUBSCRIBED

# %%
for key in user:
  print(key.title(), '=>', user[key])
# Out:
# Name => Mary Smith
# Email => john.mckinley@examplepetstore.com
# Age => 30
# Subscribed => True

# %%
for key, value in user.items():
  print(key, value)
# Out:
# name Mary Smith
# email john.mckinley@examplepetstore.com
# age 30
# subscribed True

# %%
# Modules
# One of the best features of python, rich builtin library to use external modules, you must import them:
import random

# %%
random.randint(0, 99)
# Out:
# 19

# %%
# Exceptions
age = "20"

# %%
if age > 73:
  print("allowed entrance")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-955003184.py in <cell line: 0>()
# ----> 1 if age > 73:
#       2   print("allowed entrance")
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
try:
  if age > 21:
    print("Allowed entrance")
except:
  print("Something went wrong")
# Out:
# Something went wrong

# %%
try:
  if age > 21:
    print("Allowed entrance")
except TypeError:
  print("Age is probably of a wrong type")
# Out:
# Age is probably of a wrong type

# %% [markdown]
# # And that's the RECAP OF PYTHON
