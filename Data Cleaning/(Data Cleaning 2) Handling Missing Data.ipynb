# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeVerse-team/python-for-data-analysis-learning-libraries/blob/main/Data%20Cleaning/(Data%20Cleaning%202)%20Handling%20Missing%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handling Missing Data
#
#
# ---
#
#
# ## Pandas Utility Function
# Similarly to `Numpy`, pandas also has utility functions to identify and detect null values:

# %%
import numpy as np
import pandas as pd

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
pd.isnull(None)
# Out:
# True

# %%
pd.isna(np.nan)
# Out:
# True

# %%
pd.isna(None)
# Out:
# True

# %% [markdown]
# The Opposite ones also exist:

# %%
pd.notnull(np.nan)
# Out:
# False

# %%
pd.notnull(None)
# Out:
# False

# %%
pd.notna(np.nan)
# Out:
# False

# %%
pd.notnull(3)
# Out:
# True

# %% [markdown]
# These functions also work with `Series` and `DataFrame`s.

# %%
pd.isna(pd.Series([1, 2, np.nan, 5]))
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
pd.notnull(pd.Series([1, np.nan, 5]))
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
pd.isnull(pd.DataFrame({
    'Column A': [1, np.nan, 7],
    'Column B': [np.nan, 2, 3],
    'Column C': [np.nan, 2, np.nan]
}))
# Out:
#    Column A  Column B  Column C
# 0     False      True      True
# 1      True     False     False
# 2     False     False      True

# %% [markdown]
# ## Pandas Operation with Missing Values
# Pandas manages missing values more gracefully than numpy. `nan` will no longer behave as "viuses", and operations will just ignore them completely:

# %%
pd.Series([1, 2, np.nan]).count()
# Out:
# np.int64(2)

# %%
pd.Series([1, 2, np.nan]).sum()
# Out:
# np.float64(3.0)

# %%
pd.Series([1, 2, np.nan]).mean()
# Out:
# np.float64(1.5)

# %% [markdown]
# ## Filtering missing Data
# As we saw with numpy, we could combine boolean selection + `pd.isnull` to filter out those `nan` and null values:

# %%
s = pd.Series([1, 2, 3, np.nan, np.nan, 4])

# %%
pd.notnull(s)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
pd.notnull(s).count()
# Out:
# np.int64(6)

# %%
s[pd.notnull(s)]
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 5    4.0
# dtype: float64

# %% [markdown]
# But both `notnull`, `isnull` and `isna` are also methods of `Series` and `DataFrames`, so we could use it that way:

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
s.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
s[s.notnull()]
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 5    4.0
# dtype: float64

# %% [markdown]
# ## Dropping the null values
# Boolean selection + `notnull()` seems a little bit verbose and repetive. And as we said before: any repetitive task will probably have a better, more DRY way. In this case, we can the `dropna` method:

# %%
s.dropna()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 5    4.0
# dtype: float64

# %% [markdown]
# ## Dropping null values on DataFrames
# You saw how simple it is to drop nas with a Series. But with DataFrames, there will be a few more things to consider, because you can't drop single values. You can only drop entire columns or rows. Let's start with a sample DataFrame:

# %%
df = pd.DataFrame({
    'Column A': [1, np.nan, 30, np.nan],
    'Column B': [2, 8, 31, np.nan],
    'Column C': [np.nan, 9, 32, 100],
    'Column D': [5, 8, 34, 110],
})

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info
# Out:
# <bound method DataFrame.info of    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110>

# %%
df.isnull()
# Out:
#    Column A  Column B  Column C  Column D
# 0     False     False      True     False
# 1      True     False     False     False
# 2     False     False     False     False
# 3      True      True     False     False

# %%
df.isnull().sum()
# Out:
# Column A    2
# Column B    1
# Column C    1
# Column D    0
# dtype: int64

# %%
df.dropna()
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %%
df.dropna(axis=1) # axis = "columns" also works
# Out:
#    Column D
# 0         5
# 1         8
# 2        34
# 3       110

# %% [markdown]
# In this case we're dropping rows. Rows containing null values are dropped from the DF. You can also use the axis parameter to drop columns containing null values:

# %%
df2 = pd.DataFrame({
    'Column A': [1, np.nan, 30],
    'Column B': [2, np.nan, 31],
    'Column C': [np.nan, np.nan, 100]
})

# %%
df2
# Out:
#    Column A  Column B  Column C
# 0       1.0       2.0       NaN
# 1       NaN       NaN       NaN
# 2      30.0      31.0     100.0

# %%
df.dropna(how='all')
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.dropna(how='any') # default
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %% [markdown]
# You can also use the thresh parameter to indicate a `threshold` (a minimum number) of non-null values for the row/column to be kept:

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.dropna(thresh = 3)
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34

# %%
df.dropna(thresh = 3, axis= "columns")
# Out:
#    Column B  Column C  Column D
# 0       2.0       NaN         5
# 1       8.0       9.0         8
# 2      31.0      32.0        34
# 3       NaN     100.0       110

# %% [markdown]
# ## Finding Null Values
# Sometimes instead than dropping the null values, we might need to replace them with some other value. This highly depends on your context and the dataset you're currently working. Sometimes a `nan` can be replaced with a `0`, sometimes it can be replaced with the `mean` of the sample, and some other times you can take the closest value. Again, it depends on the context. We'll show you the different methods and mechanisms and you can then apply them to your own problem.

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %% [markdown]
# **Filling the nulls with a arbitrary value**

# %%
s.fillna("empty")
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3    empty
# 4    empty
# 5      4.0
# dtype: object

# %%
s.fillna(s.mean())
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    2.5
# 4    2.5
# 5    4.0
# dtype: float64

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %% [markdown]
# **Filling nulls with contiguous (close) values**
#
# The `method` argument is used to fill null values with other values close to that null one:

# %%
s.fillna(method = "ffill")
# Out:
# /tmp/ipython-input-374771455.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s.fillna(method = "ffill")
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# 4    3.0
# 5    4.0
# dtype: float64

# %%
s.fillna(method="bfill")
# Out:
# /tmp/ipython-input-1815258262.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s.fillna(method="bfill")
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    4.0
# 5    4.0
# dtype: float64

# %% [markdown]
# This can still leave null values at the extremes of the Series/DataFrame:

# %%
pd.Series([np.nan, 3, np.nan, 9]).fillna(method="ffill")
# Out:
# /tmp/ipython-input-3675221024.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.Series([np.nan, 3, np.nan, 9]).fillna(method="ffill")
# 0    NaN
# 1    3.0
# 2    3.0
# 3    9.0
# dtype: float64

# %%
pd.Series([1, np.nan, 3, np.nan, np.nan]).fillna(method="bfill")
# Out:
# /tmp/ipython-input-2023338817.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.Series([1, np.nan, 3, np.nan, np.nan]).fillna(method="bfill")
# 0    1.0
# 1    3.0
# 2    3.0
# 3    NaN
# 4    NaN
# dtype: float64

# %% [markdown]
# ## Filling null values on DataFrames
# The `fillna` method also works on `DataFrame` and it works similarly. The main differences are that you can specify the `axis` (as usual, rows or columns) to use to fill the values (specially for methods) and that you have more control on the values passed:

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.fillna({'Column A': 0, 'Column B': 99, 'Column C': df['Column C'].mean()})
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0      47.0         5
# 1       0.0       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       0.0      99.0     100.0       110

# %%
df.fillna(method="ffill", axis =0)
# Out:
# /tmp/ipython-input-314689987.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", axis =0)
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       1.0       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3      30.0      31.0     100.0       110

# %%
df.fillna(method='ffill', axis=1)
# Out:
# /tmp/ipython-input-901808322.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', axis=1)
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       2.0       5.0
# 1       NaN       8.0       9.0       8.0
# 2      30.0      31.0      32.0      34.0
# 3       NaN       NaN     100.0     110.0

# %% [markdown]
# ## Checking If there are NAs
# The question is: Does this `Series` or `DataFrame` contain any missing value? The answer should be yes or no: `True` or `False` How can you verify it?
#
# ---
#
# ### Example 1: Cheking the length
# If there are missing values, `s.dropna()` will have less elements that `s`:

# %%
s.dropna().count()
# Out:
# np.int64(4)

# %%
missing_values = len(s.dropna()) != len(s)
missing_values
# Out:
# True

# %% [markdown]
# There's also a `count` method, that excludes `nan` form it's result:

# %%
len(s)
# Out:
# 6

# %%
s.count() # So we could just do:
# Out:
# np.int64(4)

# %%
missing_values = s.count() != len(s)
missing_values
# Out:
# np.True_

# %% [markdown]
# ## More Pythonic solution `any`
# The mehthods `any` and `all` check if either there's `any` True value in a Series or `all` the values are `True`. They work in the same wayas in PYthon:

# %%
pd.Series([True, False, False]).any()
# Out:
# np.True_

# %%
pd.Series([True, False, False]).all()
# Out:
# np.False_

# %%
pd.Series([True, True, True]).all()
# Out:
# np.True_

# %% [markdown]
# The `isnull()` method returned a Boolean `Series` with `True` values wherever there was a `nan`:

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %% [markdown]
# so we can just use the `any` method with the boolean array returned:

# %%
pd.Series([1, np.nan]).isnull().any()
# Out:
# np.True_

# %%
pd.Series([1, 2]).isnull().any()
# Out:
# np.False_

# %%
s.isnull().any()
# Out:
# np.True_

# %% [markdown]
# A more strict version would check only the `values` of the Series:

# %%
s.isnull().values
# Out:
# array([False, False, False,  True,  True, False])

# %%
s.isnull().values.any()
# Out:
# np.True_
