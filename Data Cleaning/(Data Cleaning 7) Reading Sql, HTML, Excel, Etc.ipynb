# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeVerse-team/python-for-data-analysis-learning-libraries/blob/main/Data%20Cleaning/(Data%20Cleaning%207)%20Reading%20Sql%2C%20HTML%2C%20Excel%2C%20Etc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reading data from relational databases
#
# In this lesson you will learn how to read SQL queries and relational database tables into DataFrame objects using pandas. Also, we'll take a look at different techniques to persist that pandas DataFrame objects to database tables.
#
# Located in Github: Data Cleaning/(Data Cleaning 7) Reading Sql, HTML, Excel, Etc.ipynb

# %%
import pandas as pd

# %% [markdown]
# # Reading data from SQL database
#
# Reading data from SQL relational databases is fairly simple and pandas support a variety of methods ot deal with it.
#
# We'll start with an example using SQLite, as It's a builtin Python package, and we don't need anything extra installed.

# %%
import sqlite3

# %% [markdown]
# In order to work with a SQLite database from Python, we first have to connect to it. We can do that using the connect function, which returns a Connection object.
#
# We'll use this example database.

# %%
conn = sqlite3.connect('chinook.db')

# %% [markdown]
# Once we have a `Connection` object, we can then create a `Cursor` object. Cursors allow us to execute SQL queries against a database:

# %%
cur = conn.cursor()

# %% [markdown]
# The `Cursor` created has a method `execute`, which will receive SQl, parameters to run against the database.
#
# The code below will fetch the first `5` rows from the `employees` table:

# %%
cur.execute('SELECT * FROM employees LIMIT 5;')

# %% [markdown]
# You may have noticed that we didn't assign the result of the above query to variable. This is becuase we need to run another connected to actually fetch the results.
#
# We can use the `fetchall` method to fetch all of the results of a query:

# %%
results = cur.fetchall()

# %%
results
# Out:
# [(1,
#   'Adams',
#   'Andrew',
#   'General Manager',
#   None,
#   '1962-02-18 00:00:00',
#   '2002-08-14 00:00:00',
#   '11120 Jasper Ave NW',
#   'Edmonton',
#   'AB',
#   'Canada',
#   'T5K 2N1',
#   '+1 (780) 428-9482',
#   '+1 (780) 428-3457',
#   'andrew@chinookcorp.com'),
#  (2,
#   'Edwards',
#   'Nancy',
#   'Sales Manager',
#   1,
#   '1958-12-08 00:00:00',
#   '2002-05-01 00:00:00',
#   '825 8 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 2T3',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-3322',
#   'nancy@chinookcorp.com'),
#  (3,
#   'Peacock',
#   'Jane',
#   'Sales Support Agent',
#   2,
#   '1973-08-29 00:00:00',
#   '2002-04-01 00:00:00',
#   '1111 6 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5M5',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-6712',
#   'jane@chinookcorp.com'),
#  (4,
#   'Park',
#   'Margaret',
#   'Sales Support Agent',
#   2,
#   '1947-09-19 00:00:00',
#   '2003-05-03 00:00:00',
#   '683 10 Street SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5G3',
#   '+1 (403) 263-4423',
#   '+1 (403) 263-4289',
#   'margaret@chinookcorp.com'),
#  (5,
#   'Johnson',
#   'Steve',
#   'Sales Support Agent',
#   2,
#   '1965-03-03 00:00:00',
#   '2003-10-17 00:00:00',
#   '7727B 41 Ave',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T3B 1Y7',
#   '1 (780) 836-9987',
#   '1 (780) 836-9543',
#   'steve@chinookcorp.com')]

# %% [markdown]
# As you can see, the results are returned as a list of tuples. Each tuple corresponds to a row in the database that we accessed. Dealing with data this way is painful.
#
# We'd need to manually add column headers, and manually parse the data. Luckily, the pandas library has an easier way, which we'll look at in the next section.

# %%
df = pd.DataFrame(results)

# %%
df.head()
# Out:
#    0        1         2                    3    4                    5   \
# 0   1    Adams    Andrew      General Manager  NaN  1962-02-18 00:00:00
# 1   2  Edwards     Nancy        Sales Manager  1.0  1958-12-08 00:00:00
# 2   3  Peacock      Jane  Sales Support Agent  2.0  1973-08-29 00:00:00
# 3   4     Park  Margaret  Sales Support Agent  2.0  1947-09-19 00:00:00
# 4   5  Johnson     Steve  Sales Support Agent  2.0  1965-03-03 00:00:00
#
#                     6                    7         8   9       10       11  \
# 0  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton  AB  Canada  T5K 2N1
# 1  2002-05-01 00:00:00         825 8 Ave SW   Calgary  AB  Canada  T2P 2T3
# 2  2002-04-01 00:00:00        1111 6 Ave SW   Calgary  AB  Canada  T2P 5M5
# 3  2003-05-03 00:00:00     683 10 Street SW   Calgary  AB  Canada  T2P 5G3
# 4  2003-10-17 00:00:00         7727B 41 Ave   Calgary  AB  Canada  T3B 1Y7
#
#                   12                 13                        14
# 0  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 3  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 4   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %% [markdown]
# Before we move on, it's good practice to close Connection objects and Cursor objects that are open. This prevents the SQLite database from being locked. When a SQLite database is locked, you may be unable to update the database, and may get errors. We can close the Cursor and the Connection like this:

# %%
cur.close()
conn.close()

# %% [markdown]
# #Using pandas `read_sql` method
#
# We can use the pandas `read_sql` function to read the results of a SQL query directly into a pandas `DataFrame`. The code below will execute the same query that we just did, but it will return a `DataFrame`. It has several advantages over the query we did above:
#
#
# *   It doesn't require us to create a Cursor object or call fetchall at the end.
# *   It automatically reads in the names of the headers from the table.
# *   It creates a DataFrame, so we can quickly explore the data.

# %%
conn = sqlite3.connect('chinook.db')

# %%
df = pd.read_sql('SELECT * FROM employees;', conn)

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
df = pd.read_sql('select * from employees;', conn,
                 index_col='EmployeeId',
                 parse_dates=['BirthDate', 'HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 1 to 8
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LastName    8 non-null      object
#  1   FirstName   8 non-null      object
#  2   Title       8 non-null      object
#  3   ReportsTo   7 non-null      float64
#  4   BirthDate   8 non-null      datetime64[ns]
#  5   HireDate    8 non-null      datetime64[ns]
#  6   Address     8 non-null      object
#  7   City        8 non-null      object
#  8   State       8 non-null      object
#  9   Country     8 non-null      object
#  10  PostalCode  8 non-null      object
#  11  Phone       8 non-null      object
#  12  Fax         8 non-null      object
#  13  Email       8 non-null      object
# dtypes: datetime64[ns](2), float64(1), object(11)
# memory usage: 960.0+ bytes

# %% [markdown]
# # Using pandas `read_sql_query` method
#
# it turns out that the `read_sql` method we saw above is just a wrapper around `real_sql_query` and `read_sql_table`.
#
# We can get the same result using `read_sql_query` method:

# %%
conn = sqlite3.connect('chinook.db')

# %%
df = pd.read_sql_query('SELECT * FROM employees LIMIT 5;', conn)

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
df = pd.read_sql_query('SELECT * FROM employees;', conn,
                       index_col='EmployeeId',
                       parse_dates=['BirthDate', 'HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %% [markdown]
# # Using `read_sql_table` method
#
# `read_sql_method` is a useful function, but it works only with SQLAlchemy, a Python SQL toolkit and object Relational Mapper.
#
# This is just a demonstration of its usage where we read the whole `employees` table.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///chinook.db')

connection = engine.connect()

# %%
df = pd.read_sql_table('employees', con = connection)

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew      General Manager        NaN 1962-02-18
# 1           2  Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 2           3  Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 3           4     Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 4           5  Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#     HireDate              Address      City State Country PostalCode  \
# 0 2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1 2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 2 2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 3 2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 4 2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# 0  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 3  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 4   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
df = pd.read_sql_table('employees', con = connection,
                       index_col='EmployeeId',
                       parse_dates=['BirthDate', 'HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
connection.close()

# %% [markdown]
# # Create tables from `DataFrame` objects
#
# Finally we can persist `DataFrame` objects we've working on in a database using the pandas `to_sql` method.
#
# Although it is easy to implement, it could be a vey slow process.

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %% [markdown]
# we can drop the table if needed.

# %%
df.to_sql?

# %%
cur = conn.cursor()

# %%
cur.execute('DROP TABLE IF EXISTS employees2;')

# %%
df.to_sql('employees2', conn)
# Out:
# 8

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %% [markdown]
# # Custom Behaviour
#
# The `if_exists` parameter define how to behave if the table aldready exists and adds a ton of flexibility. Letting you decide wheather to `replace` current database data, `append` new data at the end , or simply `fail` if database aldready exists.

# %%
pd.DataFrame().to_sql('employees2',
                      conn,
                      if_exists='replace')
# Out:
# 0

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
# Empty DataFrame
# Columns: [index]
# Index: []

# %%
df.to_sql('employees2',
          conn,
          if_exists='replace')
# Out:
# 8

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
conn.close()

# %% [markdown]
# # Reading HTML tables
#
# In this lecture we'll learn how to read and parse HTML tables from websites into a list of `dataframe` objects to work with.

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (5.4.0)

# %%
import pandas as pd

# %% [markdown]
# # Parsing raw HTML strings
#
# Another useful pandas method is `read_html()`. This method will read HTML tables from a given URL, a file-like object, or a raw string containing HTML, and return a list of `DataFrame` objects.
#
# Let's try to read the following `html_string` into a `DataFrame`.
#
#
#
# ```
# html_string = """
# <table>
#     <thead>
#       <tr>
#         <th>Order date</th>
#         <th>Region</th>
#         <th>Item</th>
#         <th>Units</th>
#         <th>Unit cost</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>1/6/2018</td>
#         <td>East</td>
#         <td>Pencil</td>
#         <td>95</td>
#         <td>1.99</td>
#       </tr>
#       <tr>
#         <td>1/23/2018</td>
#         <td>Central</td>
#         <td>Binder</td>
#         <td>50</td>
#         <td>19.99</td>
#       </tr>
#       <tr>
#         <td>2/9/2018</td>
#         <td>Central</td>
#         <td>Pencil</td>
#         <td>36</td>
#         <td>4.99</td>
#       </tr>
#       <tr>
#         <td>3/15/2018</td>
#         <td>West</td>
#         <td>Pen</td>
#         <td>27</td>
#         <td>19.99</td>
#       </tr>
#     </tbody>
# </table>
# ```

# %%
from IPython.core.display import display, HTML

# %%
html_string = """
<table>
    <thead>
      <tr>
        <th>Order date</th>
        <th>Region</th>
        <th>Item</th>
        <th>Units</th>
        <th>Unit cost</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td>1/6/2018</td>
        <td>East</td>
        <td>Pencil</td>
        <td>95</td>
        <td>1.99</td>
      </tr>
      <tr>
        <td>1/23/2018</td>
        <td>Central</td>
        <td>Binder</td>
        <td>50</td>
        <td>19.99</td>
      </tr>
      <tr>
        <td>2/9/2018</td>
        <td>Central</td>
        <td>Pencil</td>
        <td>36</td>
        <td>4.99</td>
      </tr>
      <tr>
        <td>3/15/2018</td>
        <td>West</td>
        <td>Pen</td>
        <td>27</td>
        <td>19.99</td>
      </tr>
    </tbody>
</table>
"""
display(HTML(html_string))
# Out:
# <table>
#     <thead>
#       <tr>
#         <th>Order date</th>
#         <th>Region</th>
#         <th>Item</th>
#         <th>Units</th>
#         <th>Unit cost</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>1/6/2018</td>
#         <td>East</td>
#         <td>Pencil</td>
#         <td>95</td>
#         <td>1.99</td>
#       </tr>
#       <tr>
#         <td>1/23/2018</td>
#         <td>Central</td>
#         <td>Binder</td>
#         <td>50</td>
#         <td>19.99</td>
#       </tr>
#       <tr>
#         <td>2/9/2018</td>
#         <td>Central</td>
#         <td>Pencil</td>
#         <td>36</td>
#         <td>4.99</td>
#       </tr>
#       <tr>
#         <td>3/15/2018</td>
#         <td>West</td>
#         <td>Pen</td>
#         <td>27</td>
#         <td>19.99</td>
#       </tr>
#     </tbody>
# </table>

# %%
dfs = pd.read_html(html_string)
# Out:
# /tmp/ipython-input-2234146965.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(html_string)

# %% [markdown]
# The `read_html` just returned one `DataFrame` object:

# %%
len(dfs)
# Out:
# 1

# %%
df = dfs[0]

df
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %% [markdown]
# Previous `DataFrame` looks quite similar to the raw HTML table, but now we have a `DataFrame object`, so we can apply any pandas operation we want to it.

# %%
df.shape
# Out:
# (4, 5)

# %%
df.loc[df['Region'] == 'Central']
# Out:
#   Order date   Region    Item  Units  Unit cost
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99

# %%
df.loc[df['Units'] > 35]
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99

# %% [markdown]
# # Defining header
# Pandas will automatically find the `header` to use thanks to the tag.
#
# But in many cases we'll find wrong or incomplete tables that make the `read_html` method parse the tables in a wrong way without the proper headers.
#
# To fix them we can use the `header` parameter.
#
#
#
# ```
# html_string = """
# <table>
#   <tr>
#     <td>Order date</td>
#     <td>Region</td>
#     <td>Item</td>
#     <td>Units</td>
#     <td>Unit cost</td>
#   </tr>
#   <tr>
#     <td>1/6/2018</td>
#     <td>East</td>
#     <td>Pencil</td>
#     <td>95</td>
#     <td>1.99</td>
#   </tr>
#   <tr>
#     <td>1/23/2018</td>
#     <td>Central</td>
#     <td>Binder</td>
#     <td>50</td>
#     <td>19.99</td>
#   </tr>
#   <tr>
#     <td>2/9/2018</td>
#     <td>Central</td>
#     <td>Pencil</td>
#     <td>36</td>
#     <td>4.99</td>
#   </tr>
#   <tr>
#     <td>3/15/2018</td>
#     <td>West</td>
#     <td>Pen</td>
#     <td>27</td>
#     <td>19.99</td>
#   </tr>
# </table>
# ```

# %%
pd.read_html(html_string)[0]
# Out:
# /tmp/ipython-input-2877898795.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(html_string)[0]
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %%
pd.read_html(html_string, header=0)[0]
# Out:
# /tmp/ipython-input-3156000096.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(html_string, header=0)[0]
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %% [markdown]
# # Parsing HTML tables from the web
#
# Now that we know how `read_html` works, go one step beyond and try to parse HTML tables directly from an URL.
#
# to do that we'll call the `read_html` mehtod with an URL as parameter.

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2019_per_game.html"

# %%
nba_tables = pd.read_html(html_url)

# %%
len(nba_tables)
# Out:
# 2

# %%
nba = nba_tables[0]

# %%
nba.head()
# Out:
#     Rk                 Player   Age Team Pos     G    GS    MP    FG   FGA  \
# 0  1.0           James Harden  29.0  HOU  PG  78.0  78.0  36.8  10.8  24.5
# 1  2.0            Paul George  28.0  OKC  SF  77.0  77.0  36.9   9.2  21.0
# 2  3.0  Giannis Antetokounmpo  24.0  MIL  PF  72.0  72.0  32.8  10.0  17.3
# 3  4.0            Joel Embiid  24.0  PHI   C  64.0  64.0  33.7   9.1  18.7
# 4  5.0           LeBron James  34.0  LAL  SF  55.0  55.0  35.2  10.1  19.9
#
#    ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  \
# 0  ...  0.8   5.8   6.6  7.5  2.0  0.7  5.0  3.1  36.1
# 1  ...  1.4   6.8   8.2  4.1  2.2  0.4  2.7  2.8  28.0
# 2  ...  2.2  10.3  12.5  5.9  1.3  1.5  3.7  3.2  27.7
# 3  ...  2.5  11.1  13.6  3.7  0.7  1.9  3.5  3.3  27.5
# 4  ...  1.0   7.4   8.5  8.3  1.3  0.6  3.6  1.7  27.4
#
#                       Awards
# 0              MVP-2,AS,NBA1
# 1  MVP-3,DPOY-3,AS,NBA1,DEF1
# 2  MVP-1,DPOY-2,AS,NBA1,DEF1
# 3  MVP-7,DPOY-4,AS,NBA2,DEF2
# 4             MVP-11,AS,NBA3
#
# [5 rows x 31 columns]

# %%
nba.head(30)
# Out:
#       Rk                 Player   Age Team Pos     G    GS    MP    FG   FGA  \
# 0    1.0           James Harden  29.0  HOU  PG  78.0  78.0  36.8  10.8  24.5
# 1    2.0            Paul George  28.0  OKC  SF  77.0  77.0  36.9   9.2  21.0
# 2    3.0  Giannis Antetokounmpo  24.0  MIL  PF  72.0  72.0  32.8  10.0  17.3
# 3    4.0            Joel Embiid  24.0  PHI   C  64.0  64.0  33.7   9.1  18.7
# 4    5.0           LeBron James  34.0  LAL  SF  55.0  55.0  35.2  10.1  19.9
# 5    6.0          Stephen Curry  30.0  GSW  PG  69.0  69.0  33.8   9.2  19.4
# 6    7.0           Devin Booker  22.0  PHO  SG  64.0  64.0  35.0   9.2  19.6
# 7    8.0          Kawhi Leonard  27.0  TOR  SF  60.0  60.0  34.0   9.3  18.8
# 8    9.0           Kevin Durant  30.0  GSW  SF  78.0  78.0  34.6   9.2  17.7
# 9   10.0          Anthony Davis  25.0  NOP   C  56.0  56.0  33.0   9.5  18.3
# 10  11.0         Damian Lillard  28.0  POR  PG  80.0  80.0  35.5   8.5  19.2
# 11  12.0           Bradley Beal  25.0  WAS  SG  82.0  82.0  36.9   9.3  19.6
# 12  13.0           Kemba Walker  28.0  CHO  PG  82.0  82.0  34.9   8.9  20.5
# 13  14.0          Blake Griffin  29.0  DET  PF  75.0  75.0  35.0   8.3  17.9
# 14  15.0     Karl-Anthony Towns  23.0  MIN   C  77.0  77.0  33.1   8.8  17.1
# 15  16.0           Kyrie Irving  26.0  BOS  PG  67.0  67.0  33.0   9.0  18.5
# 16  17.0       Donovan Mitchell  22.0  UTA  SG  77.0  77.0  33.7   8.6  19.9
# 17  18.0            Zach LaVine  23.0  CHI  SG  63.0  62.0  34.5   8.4  18.0
# 18  19.0      Russell Westbrook  30.0  OKC  PG  73.0  73.0  36.0   8.6  20.2
# 19  20.0          Klay Thompson  28.0  GSW  SG  78.0  78.0  34.0   8.4  18.0
# 20  21.0          Julius Randle  24.0  NOP  PF  73.0  49.0  30.6   7.8  14.9
# 21  22.0      LaMarcus Aldridge  33.0  SAS   C  81.0  81.0  33.2   8.4  16.3
# 22  23.0          DeMar DeRozan  29.0  SAS  SG  77.0  77.0  34.9   8.2  17.1
# 23  24.0            Luka Dončić  19.0  DAL  SG  72.0  72.0  32.2   7.0  16.5
# 24  25.0           Jrue Holiday  28.0  NOP  SG  67.0  67.0  35.9   8.2  17.3
# 25  26.0            Mike Conley  31.0  MEM  PG  70.0  70.0  33.5   7.0  16.0
# 26  27.0       D'Angelo Russell  22.0  BRK  PG  81.0  81.0  30.2   8.1  18.7
# 27  28.0            CJ McCollum  27.0  POR  SG  70.0  70.0  33.9   8.2  17.8
# 28  29.0         Nikola Vučević  28.0  ORL   C  80.0  80.0  31.4   8.8  16.9
# 29  30.0            Buddy Hield  26.0  SAC  SG  82.0  82.0  31.9   7.6  16.6
#
#     ...  ORB   DRB   TRB   AST  STL  BLK  TOV   PF   PTS  \
# 0   ...  0.8   5.8   6.6   7.5  2.0  0.7  5.0  3.1  36.1
# 1   ...  1.4   6.8   8.2   4.1  2.2  0.4  2.7  2.8  28.0
# 2   ...  2.2  10.3  12.5   5.9  1.3  1.5  3.7  3.2  27.7
# 3   ...  2.5  11.1  13.6   3.7  0.7  1.9  3.5  3.3  27.5
# 4   ...  1.0   7.4   8.5   8.3  1.3  0.6  3.6  1.7  27.4
# 5   ...  0.7   4.7   5.3   5.2  1.3  0.4  2.8  2.4  27.3
# 6   ...  0.6   3.5   4.1   6.8  0.9  0.2  4.1  3.1  26.6
# 7   ...  1.3   6.0   7.3   3.3  1.8  0.4  2.0  1.5  26.6
# 8   ...  0.4   5.9   6.4   5.9  0.7  1.1  2.9  2.0  26.0
# 9   ...  3.1   8.9  12.0   3.9  1.6  2.4  2.0  2.4  25.9
# 10  ...  0.9   3.8   4.6   6.9  1.1  0.4  2.7  1.9  25.8
# 11  ...  1.1   3.9   5.0   5.5  1.5  0.7  2.7  2.8  25.6
# 12  ...  0.6   3.8   4.4   5.9  1.2  0.4  2.6  1.6  25.6
# 13  ...  1.3   6.2   7.5   5.4  0.7  0.4  3.4  2.7  24.5
# 14  ...  3.4   9.0  12.4   3.4  0.9  1.6  3.1  3.8  24.4
# 15  ...  1.1   3.9   5.0   6.9  1.5  0.5  2.6  2.5  23.8
# 16  ...  0.8   3.3   4.1   4.2  1.4  0.4  2.8  2.7  23.8
# 17  ...  0.6   4.0   4.7   4.5  1.0  0.4  3.4  2.2  23.7
# 18  ...  1.5   9.6  11.1  10.7  1.9  0.5  4.5  3.4  22.9
# 19  ...  0.5   3.4   3.8   2.4  1.1  0.6  1.5  2.0  21.5
# 20  ...  2.2   6.5   8.7   3.1  0.7  0.6  2.8  3.4  21.4
# 21  ...  3.1   6.1   9.2   2.4  0.5  1.3  1.8  2.2  21.3
# 22  ...  0.7   5.3   6.0   6.2  1.1  0.5  2.6  2.3  21.2
# 23  ...  1.2   6.6   7.8   6.0  1.1  0.3  3.4  1.9  21.2
# 24  ...  1.1   3.9   5.0   7.7  1.6  0.8  3.1  2.2  21.2
# 25  ...  0.6   2.8   3.4   6.4  1.3  0.3  1.9  1.8  21.1
# 26  ...  0.7   3.2   3.9   7.0  1.2  0.2  3.1  1.7  21.1
# 27  ...  0.9   3.1   4.0   3.0  0.8  0.4  1.5  2.5  21.0
# 28  ...  2.8   9.2  12.0   3.8  1.0  1.1  2.0  2.0  20.8
# 29  ...  1.3   3.7   5.0   2.5  0.7  0.4  1.8  2.5  20.7
#
#                        Awards
# 0               MVP-2,AS,NBA1
# 1   MVP-3,DPOY-3,AS,NBA1,DEF1
# 2   MVP-1,DPOY-2,AS,NBA1,DEF1
# 3   MVP-7,DPOY-4,AS,NBA2,DEF2
# 4              MVP-11,AS,NBA3
# 5               MVP-5,AS,NBA1
# 6                         NaN
# 7   MVP-9,DPOY-6,AS,NBA2,DEF2
# 8               MVP-8,AS,NBA2
# 9                          AS
# 10              MVP-6,AS,NBA2
# 11                         AS
# 12                    AS,NBA3
# 13                    AS,NBA3
# 14                         AS
# 15                    AS,NBA2
# 16                        NaN
# 17                        NaN
# 18             MVP-10,AS,NBA3
# 19                    AS,DEF2
# 20                        NaN
# 21                         AS
# 22                        NaN
# 23                      ROY-1
# 24                       DEF2
# 25                        NaN
# 26                         AS
# 27                        NaN
# 28                         AS
# 29                        NaN
#
# [30 rows x 31 columns]

# %% [markdown]
# # Complex Examples
#
# We can also use the `requests` module to get the HTML code from URL to parse it into `DataFrame` objects.
#
# if we look at the given url we can see multiple tables about the director SS rajamouli.
#
# we want to keep the table with information about each season.

# %%
import requests

html_url = "https://en.wikipedia.org/wiki/The_Simpsons"

# %%
from io import StringIO
import requests

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

r = requests.get(html_url, headers=headers)
r.raise_for_status() # This will raise an HTTPError for bad responses (4xx or 5xx)

# Removing header=0 to allow pandas to infer the header more flexibly
wiki_tables = pd.read_html(StringIO(r.text))

# %%
len(wiki_tables)
# Out:
# 50

# %%
simpsons = wiki_tables[2]

# %%
simpsons.head()
# Out:
#              No. of episodes    Originally aired                   \
#              No. of episodes     Season premiere    Season finale
#              No. of episodes     Season premiere    Season finale
# Season
# (3, 1991–92)              24  September 19, 1991  August 27, 1992
# (4, 1992–93)              22  September 24, 1992     May 13, 1993
# (5, 1993–94)              22  September 30, 1993     May 19, 1994
# (6, 1994–95)              25   September 4, 1994     May 21, 1995
# (7, 1995–96)              25  September 17, 1995     May 19, 1996
#
#                                                                  \
#                                                  Time slot (ET)
#                                                  Time slot (ET)
# Season
# (3, 1991–92)                                   Thursday 8:00 pm
# (4, 1992–93)                                   Thursday 8:00 pm
# (5, 1993–94)                                   Thursday 8:00 pm
# (6, 1994–95)                                     Sunday 8:00 pm
# (7, 1995–96)  Sunday 8:00 pm (Episodes 1–24) Sunday 8:30 pm ...
#
#                                           Viewership                       \
#              Avg. households / viewers (in millions) Most watched episode
#              Avg. households / viewers (in millions)   Viewers (millions)
# Season
# (3, 1991–92)                          12m h.[n1][n3]            25.5[166]
# (4, 1992–93)                       12.1m h.[n1][167]            28.6[168]
# (5, 1993–94)                        10.5m h.[n1][n4]            24.0[169]
# (6, 1994–95)                          9m h.[n1][170]            22.2[171]
# (7, 1995–96)                          8m h.[n1][172]            22.6[173]
#
#
#
#                                 Episode title
# Season
# (3, 1991–92)                  "Colonel Homer"
# (4, 1992–93)              "Lisa's First Word"
# (5, 1993–94)         "Treehouse of Horror IV"
# (6, 1994–95)          "Treehouse of Horror V"
# (7, 1995–96)  "Who Shot Mr. Burns? – Part II"

# %% [markdown]
# Quick clean on the table: remove extra header rows and set `Season` as index.

# %%
# Flatten the MultiIndex columns to a single level, using the second level values.
simpsons.columns = simpsons.columns.get_level_values(1)

# %%
# simpsons.set_index('Season', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2920111208.py in <cell line: 0>()
# ----> 1 simpsons.set_index('Season', inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Season'] are in the columns"

# %% [markdown]
# Which season has the lowest number of episodes?

# %%
simpsons['No of episodes'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'No of episodes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1480898040.py in <cell line: 0>()
# ----> 1 simpsons['No of episodes'].unique()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4099         if is_single_key:
#    4100             if self.columns.nlevels > 1:
# -> 4101                 return self._getitem_multilevel(key)
#    4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    4157     def _getitem_multilevel(self, key):
#    4158         # self.columns is a MultiIndex
# -> 4159         loc = self.columns.get_loc(key)
#    4160         if isinstance(loc, (slice, np.ndarray)):
#    4161             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    3038
#    3039         if not isinstance(key, tuple):
# -> 3040             loc = self._get_level_indexer(key, level=0)
#    3041             return _maybe_to_slice(loc)
#    3042
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3389
#    3390         else:
# -> 3391             idx = self._get_loc_single_level_index(level_index, key)
#    3392
#    3393             if level > 0 or self._lexsort_depth == 0:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2978             return -1
#    2979         else:
# -> 2980             return level_index.get_loc(key)
#    2981
#    2982     def get_loc(self, key):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'No of episodes'

# %%
simpsons = simpsons.loc[simpsons['No. ofepisodes'] != 'TBA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'No. ofepisodes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1694340233.py in <cell line: 0>()
# ----> 1 simpsons = simpsons.loc[simpsons['No. ofepisodes'] != 'TBA']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4099         if is_single_key:
#    4100             if self.columns.nlevels > 1:
# -> 4101                 return self._getitem_multilevel(key)
#    4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    4157     def _getitem_multilevel(self, key):
#    4158         # self.columns is a MultiIndex
# -> 4159         loc = self.columns.get_loc(key)
#    4160         if isinstance(loc, (slice, np.ndarray)):
#    4161             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    3038
#    3039         if not isinstance(key, tuple):
# -> 3040             loc = self._get_level_indexer(key, level=0)
#    3041             return _maybe_to_slice(loc)
#    3042
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3389
#    3390         else:
# -> 3391             idx = self._get_loc_single_level_index(level_index, key)
#    3392
#    3393             if level > 0 or self._lexsort_depth == 0:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2978             return -1
#    2979         else:
# -> 2980             return level_index.get_loc(key)
#    2981
#    2982     def get_loc(self, key):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'No. ofepisodes'

# %%
min_season = simpsons['No of episodes'].min()

min_season

# %%
simpsons.loc[simpsons['No of episodes'] == min_season]

# %% [markdown]
# # Save to CSV file
#
# Finally save the `DataFrame` to a CSV file as we saw on previous lectures.

# %%
simpsons.head()
# Out:
#              No. of episodes    Originally aired                   \
#              No. of episodes     Season premiere    Season finale
#              No. of episodes     Season premiere    Season finale
# Season
# (3, 1991–92)              24  September 19, 1991  August 27, 1992
# (4, 1992–93)              22  September 24, 1992     May 13, 1993
# (5, 1993–94)              22  September 30, 1993     May 19, 1994
# (6, 1994–95)              25   September 4, 1994     May 21, 1995
# (7, 1995–96)              25  September 17, 1995     May 19, 1996
#
#                                                                  \
#                                                  Time slot (ET)
#                                                  Time slot (ET)
# Season
# (3, 1991–92)                                   Thursday 8:00 pm
# (4, 1992–93)                                   Thursday 8:00 pm
# (5, 1993–94)                                   Thursday 8:00 pm
# (6, 1994–95)                                     Sunday 8:00 pm
# (7, 1995–96)  Sunday 8:00 pm (Episodes 1–24) Sunday 8:30 pm ...
#
#                                           Viewership                       \
#              Avg. households / viewers (in millions) Most watched episode
#              Avg. households / viewers (in millions)   Viewers (millions)
# Season
# (3, 1991–92)                          12m h.[n1][n3]            25.5[166]
# (4, 1992–93)                       12.1m h.[n1][167]            28.6[168]
# (5, 1993–94)                        10.5m h.[n1][n4]            24.0[169]
# (6, 1994–95)                          9m h.[n1][170]            22.2[171]
# (7, 1995–96)                          8m h.[n1][172]            22.6[173]
#
#
#
#                                 Episode title
# Season
# (3, 1991–92)                  "Colonel Homer"
# (4, 1992–93)              "Lisa's First Word"
# (5, 1993–94)         "Treehouse of Horror IV"
# (6, 1994–95)          "Treehouse of Horror V"
# (7, 1995–96)  "Who Shot Mr. Burns? – Part II"

# %%
simpsons.to_csv('out.csv')

# %%
pd.read_csv('out.csv', index_col='Viewership').head()
# Out:
#                                              Unnamed: 0  No. of episodes  \
# Viewership
# Avg. households / viewers (in millions)             NaN  No. of episodes
# Avg. households / viewers (in millions)             NaN  No. of episodes
# NaN                                              Season              NaN
# 12m h.[n1][n3]                           (3, '1991–92')               24
# 12.1m h.[n1][167]                        (4, '1992–93')               22
#
#                                            Originally aired  \
# Viewership
# Avg. households / viewers (in millions)     Season premiere
# Avg. households / viewers (in millions)     Season premiere
# NaN                                                     NaN
# 12m h.[n1][n3]                           September 19, 1991
# 12.1m h.[n1][167]                        September 24, 1992
#
#                                         Originally aired.1 Originally aired.2  \
# Viewership
# Avg. households / viewers (in millions)      Season finale     Time slot (ET)
# Avg. households / viewers (in millions)      Season finale     Time slot (ET)
# NaN                                                    NaN                NaN
# 12m h.[n1][n3]                             August 27, 1992   Thursday 8:00 pm
# 12.1m h.[n1][167]                             May 13, 1993   Thursday 8:00 pm
#
#                                                  Viewership.1  \
# Viewership
# Avg. households / viewers (in millions)  Most watched episode
# Avg. households / viewers (in millions)    Viewers (millions)
# NaN                                                       NaN
# 12m h.[n1][n3]                                      25.5[166]
# 12.1m h.[n1][167]                                   28.6[168]
#
#                                                  Viewership.2
# Viewership
# Avg. households / viewers (in millions)  Most watched episode
# Avg. households / viewers (in millions)         Episode title
# NaN                                                       NaN
# 12m h.[n1][n3]                                "Colonel Homer"
# 12.1m h.[n1][167]                         "Lisa's First Word"

# %% [markdown]
# # Reading Excel files
#
# In this lecture we'll learn how to read Excel files (.xlsx) and its sheets into a pandas `DataFrames`, and how to export that `DataFrames` to different sheets and Excel files using the pandas `ExcelWriter` and `to_excel` methods.

# %%
import pandas as pd

# %% [markdown]
# # The `read_excel` method
#
# We'll begin with the **read_excel** method, that let us read Excel files into a `DataFrame`.
#
# This method supports both XLS and XLSX file extensions from a local filesystem or URL and has a broad set of parameters to configure how the data will be read and parsed. These parameters are very similar to the parameters we saw on previous lectures where we introduced the read_csv method. The most common parameters are as follows:
#
# filepath: Path of the file to be read.
#
# sheet_name: Strings are used for sheet names. Integers are used in zero-indexed sheet positions. Lists of strings/integers are used to request multiple sheets. Specify None to get all sheets.
#
# header: Index of the row containing the names of the columns (None if none).
#
# index_col: Index of the column or sequence of indexes that should be used as index of rows of the data.
#
# names: Sequence containing the names of the columns (used together with header = None).
#
# skiprows: Number of rows or sequence of row indexes to ignore in the load.
#
# na_values: Sequence of values that, if found in the file, should be treated as NaN.
#
# dtype: Dictionary in which the keys will be column names and the values will be types of NumPy to which their content must be converted.
#
# parse_dates: Flag that indicates if Python should try to parse data with a format similar to dates as dates. You can enter a list of column names that must be joined for the parsing as a date.
#
# date_parser: Function to use to try to parse dates.
#
# nrows: Number of rows to read from the beginning of the file.
#
# skip_footer: Number of rows to ignore at the end of the file.
#
# squeeze: Flag that indicates that if the data read only contains one column the result is a Series instead of a DataFrame.
#
# thousands: Character to use to detect the thousands separator.
#
# Full read_excel documentation can be found here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html.
#
# In this case we'll try to read our products.xlsx Excel file.
#
# This file contains records of products with its price, brand, description and merchant information on different sheets.

# %% [markdown]
# # Reading our first Excel file
# Everytime we call `read_excel` method, we'll need to pass an explicit `filepath` parameter indicating the path where our Excel file is.
#
# Any valid string path is acceptable. The string could be a URL. Valid URL schemes include HTTP, FTP, S3, and file. For file URLs, a host is expected. A local file could be: `file://localhost/path/to/table.xlsx`.

# %%
df = pd.read_excel('products.xlsx')

# %%
df.head(10)
# Out:
#              product_id   price  merchant_id                     brand  \
# 0  AVphzgbJLJeJML43fA0o  104.99         1001                     Sanus
# 1  AVpgMuGwLJeJML43KY_c   69.00         1002                   Boytone
# 2  AVpe9FXeLJeJML43zHrq   23.99         1001                     DENAQ
# 3  AVpfVJXu1cnluZ0-iwTT  290.99         1001                 DreamWave
# 4  AVphUeKeilAPnD_x3-Be  244.01         1004                    Yamaha
# 5  AVpi6aLv1cnluZ0-Rv8A  254.99         1001  Universal Remote Control
# 6  AVpf0Nyo1cnluZ0-rzhu  499.00         1005                      Bose
# 7  AWOpOCd2YSSHbkXw07ei  224.99         1001                   Samsung
# 8  AV2Z1Efc-jtxr-f39lm6  139.99         1001                   Corsair
# 9  AVpgNkVc1cnluZ0-yJB6   55.99         1001              Outdoor Tech
#
#                                                 name
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  NS-SP1800BL 5.1-Channel Home Theater System (B...
# 5  Universal Remote Control - 48-Device Universal...
# 6  Acoustimass 6 Series V Home Theater Speaker Sy...
# 7  Samsung - 850 PRO 512GB Internal SATA III Soli...
# 8  Corsair Vengeance LPX 16GB (2x8GB) DDR4 DRAM 3...
# 9        Outdoor Tech Buckshot Pro Bluetooth Speaker

# %% [markdown]
# # First row behaviour with header parameter
#
# The Excel file we're reading has the following columns:
#
# `product_id`
#
# `price`
#
# `merchant_id`
#
# `brand`
#
# `name`
#
# The first row (0-index) of the data has that column names, so we keep the implicit `header=0` parameter to let Pandas assign this first row as headers. We can overwrite this behavior defining explicitly the `header` parameter.

# %%
pd.read_excel('products.xlsx').head()
# Out:
#              product_id   price  merchant_id      brand  \
# 0  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1  AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4  AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                 name
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %%
pd.read_excel('products.xlsx',
              header=None).head()
# Out:
#                       0       1            2          3  \
# 0            product_id   price  merchant_id      brand
# 1  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 2  AVpgMuGwLJeJML43KY_c      69         1002    Boytone
# 3  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 4  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
#
#                                                    4
# 0                                               name
# 1  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 2  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 4  DreamWave - Tremor Portable Bluetooth Speaker ...

# %% [markdown]
# # Adding index to our data using `index_col` parameter
# By default, pandas will automatically assign a numeric autoincremental index or row label starting with zero.
#
# You may want to leave the default index as such if your data doesn’t have a column with unique values that can serve as a better index.
#
# In case there is a column that you feel would serve as a better index, you can override the default behavior by setting `index_col` property to a column. It takes a numeric value or a string for setting a single column as index or a list of numeric values for creating a multi-index.
#
# In our data, we are choosing the first column, `product_id`, as index (index=0) by passing zero to the `index_col` argument.

# %%
df = pd.read_excel('products.xlsx', index_col=[0])
df.head()
# Out:
#                        price  merchant_id      brand  \
# product_id
# AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                                    name
# product_id
# AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq           DENAQ - AC Adapter for TOSHIBA SATELLITE
# AVpfVJXu1cnluZ0-iwTT  DreamWave - Tremor Portable Bluetooth Speaker ...
# AVphUeKeilAPnD_x3-Be  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %% [markdown]
# # Selecting specific sheets

# %%
products = pd.read_excel('products.xlsx',
                         sheet_name='Products',
                         index_col='product_id')
products.head()
# Out:
#                        price  merchant_id      brand  \
# product_id
# AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                                    name
# product_id
# AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq           DENAQ - AC Adapter for TOSHIBA SATELLITE
# AVpfVJXu1cnluZ0-iwTT  DreamWave - Tremor Portable Bluetooth Speaker ...
# AVphUeKeilAPnD_x3-Be  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %%
merchants = pd.read_excel('products.xlsx',
                          sheet_name='Merchants',
                          index_col = 'merchant_id')
merchants.head()
# Out:
#                      merchant
# merchant_id
# 1001              Bestbuy.com
# 1002              Walmart.com
# 1003              Bestbuy.com
# 1004                 Growkart
# 1005         bhphotovideo.com

# %% [markdown]
# The `Excelfile` class
#
# Another approach on reading Excel data is using the `ExcelFile` class for parsing tabular Excel sheets into `DataFrame` objects.
#
# This `ExcelFile` will let us work with sheets easily, and will be faster than the previous `read_excel` method.

# %%
excel_file = pd.ExcelFile('products.xlsx')

# %% [markdown]
# We can now explore the sheets on that excel file with `sheet_names`:

# %%
excel_file.sheet_names
# Out:
# ['Products', 'Descriptions', 'Merchants']

# %% [markdown]
# And parse specified sheet(s) into a Pandas' `DataFrame` using ExcelFile's `parse()` method.
#
# Everytime we call `parse()` method, we'll need to pass an explicit `sheet_name` parameter indicating which sheet from the Excel file we want to be parsed. First sheet will be parsed by default.

# %%
products = excel_file.parse('Products')
products.head()
# Out:
#              product_id   price  merchant_id      brand  \
# 0  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1  AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4  AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                 name
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %%
products = excel_file.parse(sheet_name='Products',
                            header=0,
                            index_col='product_id')
products.head()
# Out:
#                        price  merchant_id      brand  \
# product_id
# AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                                    name
# product_id
# AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq           DENAQ - AC Adapter for TOSHIBA SATELLITE
# AVpfVJXu1cnluZ0-iwTT  DreamWave - Tremor Portable Bluetooth Speaker ...
# AVphUeKeilAPnD_x3-Be  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %%
products.dtypes
# Out:
# price          float64
# merchant_id      int64
# brand           object
# name            object
# dtype: object

# %%
merchants = excel_file.parse('Merchants',
                             index_col='merchant_id')
merchants.head()
# Out:
#                      merchant
# merchant_id
# 1001              Bestbuy.com
# 1002              Walmart.com
# 1003              Bestbuy.com
# 1004                 Growkart
# 1005         bhphotovideo.com

# %%
merchants.dtypes
# Out:
# merchant    object
# dtype: object

# %% [markdown]
# # Save to Excel file
#
# Finally we can save our `DataFrame` as a Excel file.

# %%
products.head()
# Out:
#                        price  merchant_id      brand  \
# product_id
# AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                                    name
# product_id
# AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq           DENAQ - AC Adapter for TOSHIBA SATELLITE
# AVpfVJXu1cnluZ0-iwTT  DreamWave - Tremor Portable Bluetooth Speaker ...
# AVphUeKeilAPnD_x3-Be  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %%
products.to_excel('out2.xlsx')
pd.read_excel('out2.xlsx').head()
# Out:
#              product_id   price  merchant_id      brand  \
# 0  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1  AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4  AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                 name
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %%
products.to_excel('out2.xlsx',
                  sheet_name='Products')

# %%
products.to_excel('out2.xlsx',
                  index=None)
pd.read_excel('out.xlsx').head()
# Out:
#     price  merchant_id      brand  \
# 0  104.99         1001      Sanus
# 1   69.00         1002    Boytone
# 2   23.99         1001      DENAQ
# 3  290.99         1001  DreamWave
# 4  244.01         1004     Yamaha
#
#                                                 name
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %% [markdown]
# # Positioning Data with `startrow` and `startcol`
#
# Suppose we wanted to insert the our data into the spreadsheet file in a position somewhere other than the top-left corner.
#
# We can shift where the `to_excel` method writes the data by using `startrow` to set the cell after which the first row will be printed, and `startcol` to set which cell after which the first column will be printed.

# %%
products.to_excel('out3.xlsx',
                  sheet_name='Products',
                  startrow=1,
                  startcol=2)

# %% [markdown]
# # Saving Multiple Sheets
#
# If we wanted to write a single `DataFrame` to a single sheet with default formatting then we are done. However, if we want to write multiple sheets and/or multiple `DataFrames`, then we will need to create an `ExcelWriter` object.
#
# The `ExcelWriter` object is included in the Pandas module and is used to `open` Excel files and handle write operations. This object behaves almost exactly like the vanilla Python open object that we used on previous courses and can be used within a `with` block.
#
#
#
# > When the `ExcelWriter` object is executed, any existing file with the same name as the output file will be overwritten.

# %%
writer = pd.ExcelWriter('out4.xlsx')
writer

# %% [markdown]
# Instead of including the file pathname in the `to_excel` call, we will use the `ExcelWriter` object `writer` instead.

# %%
with writer:
    products.to_excel(writer, sheet_name='Products')
pd.read_excel('out4.xlsx', sheet_name='Products').head()
# Out:
#              product_id   price  merchant_id      brand  \
# 0  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1  AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4  AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                 name
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %% [markdown]
# We can now add another `Merchants` sheet simply using the `writer` object:

# %%
with pd.ExcelWriter('out4.xlsx') as writer:
    products.to_excel(writer, sheet_name='Products')
    merchants.to_excel(writer, sheet_name='Merchants')

# %% [markdown]
# In that case the resulting out.xlxs file will have two sheets `Products` and `Merchants`.
